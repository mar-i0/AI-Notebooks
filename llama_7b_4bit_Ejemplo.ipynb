# %% [markdown]
# <a href="https://colab.research.google.com/github/mar-i0/AI-Notebooks/blob/main/llama_7b_4bit_Ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.- Bajamos este repositorio a ver si tenemos más suerte**

# %%
# !git clone https://github.com/qwopqwop200/GPTQ-for-LLaMa
# Out:
# Cloning into 'GPTQ-for-LLaMa'...
# remote: Enumerating objects: 1426, done.
# remote: Counting objects: 100% (728/728), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 1426 (delta 657), reused 552 (delta 529), pack-reused 698
# Receiving objects: 100% (1426/1426), 2.62 MiB | 4.88 MiB/s, done.
# Resolving deltas: 100% (782/782), done.

# %% [markdown]
# **2.- Entramos dentro de la carpeta**

# %%
# %cd GPTQ-for-LLaMa
# Out:
# /content/GPTQ-for-LLaMa

# %% [markdown]
# **3.- Cambiamos el git del fichero requirements por este otro: git+https://github.com/zphang/transformers@660dd6e2bbc9255aacd0e60084cf15df1b6ae00d#egg=transformers**

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-on7pjtiw
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-on7pjtiw
#   Resolved https://github.com/huggingface/transformers to commit 28f26c107b4a1c5c7e32ed4d9575622da0627a40
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.29.0.dev0-py3-none-any.whl size=6929182 sha256=4027ac0cd4fefeb90434b91f535c7112cb22342bb11dbd2e965d9aa3b0303611
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e4fb5pwe/wheels/14/a0/7b/8f6b25ba4110aa215fcb8d6aedd6cd4f9b9b6619190999ac2b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.27.0.dev0
# ...

# %% [markdown]
# **4.- Nos bajamos el modelo de llama-7b-4bit de HuggingFace**

# %%
# !wget https://huggingface.co/decapoda-research/llama-7b-hf-int4/resolve/main/llama-7b-4bit.pt
# Out:
# --2023-04-15 15:32:30--  https://huggingface.co/decapoda-research/llama-7b-hf-int4/resolve/main/llama-7b-4bit.pt
# Resolving huggingface.co (huggingface.co)... 13.227.219.63, 13.227.219.41, 13.227.219.125, ...
# Connecting to huggingface.co (huggingface.co)|13.227.219.63|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# **5.- Nos bajamos CUDA**

# %%
#!python setup_cuda.py install
# !nvidia-smi
# Out:
# Sat Apr 15 15:32:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# **6.- Instalamos y provamos TensorRT**

# %%
# !pip install --upgrade tensorrt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.2/819.2 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.5/823.5 kB 52.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.6/719.6 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.5/379.5 MB 4.1 MB/s eta 0:00:00
# ...

# %%
#!pip install pycuda
#!pip install tensorrt
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
   import tensorflow as tf
   from tensorflow.python.compiler.tensorrt import trt_convert as trt

   print("TensorFlow version: ", tf.__version__)
   print("TensorRT version: ", trt.__version__)
# Out:
# TensorFlow version:  2.12.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ebd5404a49c6> in <cell line: 5>()
#       3
#       4 print("TensorFlow version: ", tf.__version__)
# ----> 5 print("TensorRT version: ", trt.__version__)
#
# AttributeError: module 'tensorflow.python.compiler.tensorrt.trt_convert' has no attribute '__version__'

# %%
# !CUDA_VISIBLE_DEVICES=0 python llama_inference.py decapoda-research/llama-7b-hf --wbits 4 --load llama-7b-4bit.pt --text "De qué color es el caballo blanco de Santiago? \n"
# Out:
# 2023-04-15 15:46:50.388884: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading model ...
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/GPTQ-for-LLaMa/llama_inference.py:129 in <module>                   │
# │                                                                              │
# │   126 │   │   args.load = args.load.as_posix()                               │
# │   127 │                                                                      │
# │   128 │   if args.load:                                                      │
# │ ❱ 129 │   │   model = load_quant(args.model, args.load, args.wbits, args.gro │
# │   130 │   else:                                                              │
# │   131 │   │   model = get_llama(args.model)                                  │
# │   132 │   │   model.eval()                                                   │
# ...

# %%
# !dpkg -l | grep TensorRT

# %%
# !ls -l
# Out:
# total 3691040
# -rw-r--r-- 1 root root       1110 Apr 15 15:31 convert_llama_weights_to_hf.py
# -rw-r--r-- 1 root root       6283 Apr 15 15:31 datautils.py
# -rw-r--r-- 1 root root       5710 Apr 15 15:31 gptq.py
# -rw-r--r-- 1 root root      11357 Apr 15 15:31 LICENSE.txt
# -rw-r--r-- 1 root root 3779492377 Mar  9 18:22 llama-7b-4bit.pt
# -rw-r--r-- 1 root root      13492 Apr 15 15:31 llama_inference_offload.py
# -rw-r--r-- 1 root root       4434 Apr 15 15:31 llama_inference.py
# -rw-r--r-- 1 root root      16783 Apr 15 15:31 llama.py
# -rw-r--r-- 1 root root        397 Apr 15 15:31 modelutils.py
# -rw-r--r-- 1 root root      18177 Apr 15 15:31 opt.py
# drwxr-xr-x 2 root root       4096 Apr 15 15:33 __pycache__
# drwxr-xr-x 3 root root       4096 Apr 15 15:33 quant
# -rw-r--r-- 1 root root       9350 Apr 15 15:31 README.md
# -rw-r--r-- 1 root root        131 Apr 15 15:31 requirements.txt
