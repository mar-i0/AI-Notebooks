# %% [markdown]
# <a href="https://colab.research.google.com/github/mar-i0/AI-Notebooks/blob/main/Dolly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install accelerate>=0.12.0 transformers[torch]==4.25.1

# %%
#Con este modelo no funciona porque consume toda la ram y a el error en colab: "Tu sesión ha fallado porque se ha usado toda la memoria RAM disponible. Si te interesa disfrutar de tiempos de ejecución con más memoria RAM, echa un vistazo a Colab Pro."
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-12b", torch_dtype=torch.bfloat16, trust_remote_code=True)

generate_text("Explain me the difference between nuclear fission and fusion.")

# %%
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-2-8b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)

generate_text("Explain me the difference between nuclear fission and fusion.")
# Out:
# ...
# 'Fission and fusion are two different process that take place in the nucleus of atom. Fission takes place when two very small nuclei collide and merge to create one larger nucleus. Fusion takes place when two similar sized nuclei merge to create a larger, more stable nucleus. The two nuclei need not be the same element. Different isotopes of the same element may undergo fusion to form a different, more stable nucleus. Conversely, two different isotopes of the same element may fuse to form a third element or some stable isotope.'

# %%
generate_text = pipeline(model="databricks/dolly-v2-12b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)

generate_text("¿De qué color es el caballo blanco de Santiago?")
# Out:
# ...
# 'El caballo blanco de Santiago es de color blanco.'
