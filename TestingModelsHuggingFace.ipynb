# %% [markdown]
# <a href="https://colab.research.google.com/github/mar-i0/AI-Notebooks/blob/main/TestingModelsHuggingFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install accelerate>=0.12.0 transformers[torch]==4.25.1

# %%
#Con este modelo no funciona porque consume toda la ram y a el error en colab: "Tu sesión ha fallado porque se ha usado toda la memoria RAM disponible. Si te interesa disfrutar de tiempos de ejecución con más memoria RAM, echa un vistazo a Colab Pro."
import torch
from transformers import pipeline

# %%
def test_model(model_name):
  generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
  generate_text("¿De qué color es el caballo blanco de Santiago?")

# %%
test_model("chavinlo/alpaca-native") #KeyError: 'llama'
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-13bd927eb72e> in <cell line: 1>()
# ----> 1 test_model("chavinlo/alpaca-native")
#
# <ipython-input-4-35736c78a79c> in test_model(model_name)
#       1 def test_model(model_name):
# ----> 2   generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
#       3   generate_text("¿De qué color es el caballo blanco de Santiago?")
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     643         hub_kwargs["_commit_hash"] = config._commit_hash
#     644     elif config is None and isinstance(model, str):
# ...

# %%
test_model("declare-lab/flan-alpaca-xl") #No da ningún mensaje al preguntarle. Carga bien. CORRECTO

# %%
test_model("anon8231489123/gpt4-x-alpaca-13b-native-4bit-128g") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("chainyo/alpaca-lora-7b") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("chavinlo/gpt4-x-alpaca") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("declare-lab/flan-alpaca-large") #carga OK pero no responde a la pregunta. CORRECTO

# %%
test_model("declare-lab/flan-alpaca-base")#carga OK pero no responde a la pregunta. CORRECTO

# %%
test_model("Dogge/alpaca-13b") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("ozcur/alpaca-native-4bit")#KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("circulus/alpaca-7b")#KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("elinas/alpaca-13b-lora-int4")#KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("declare-lab/flan-alpaca-xxl") #No hay suficiente ram pero carga bien CORRECTO

# %%
test_model("elinas/alpaca-30b-lora-int4") #KeyError: 'llama'
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-32dbf5800aeb> in <cell line: 1>()
# ----> 1 test_model("elinas/alpaca-30b-lora-int4")
#
# <ipython-input-4-35736c78a79c> in test_model(model_name)
#       1 def test_model(model_name):
# ----> 2   generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
#       3   generate_text("¿De qué color es el caballo blanco de Santiago?")
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     643         hub_kwargs["_commit_hash"] = config._commit_hash
#     644     elif config is None and isinstance(model, str):
# ...

# %%
test_model("chavinlo/alpaca-13b") #KeyError: 'llama'
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3ded68b8d2e3> in <cell line: 1>()
# ----> 1 test_model("chavinlo/alpaca-13b")
#
# <ipython-input-4-35736c78a79c> in test_model(model_name)
#       1 def test_model(model_name):
# ----> 2   generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
#       3   generate_text("¿De qué color es el caballo blanco de Santiago?")
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     643         hub_kwargs["_commit_hash"] = config._commit_hash
#     644     elif config is None and isinstance(model, str):
# ...

# %%
test_model("Bradarr/gpt4-x-alpaca-13b-native-4bit-128g-cuda") #KeyError: 'llama'
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-269749e699a5> in <cell line: 1>()
# ----> 1 test_model("Bradarr/gpt4-x-alpaca-13b-native-4bit-128g-cuda")
#
# <ipython-input-4-35736c78a79c> in test_model(model_name)
#       1 def test_model(model_name):
# ----> 2   generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
#       3   generate_text("¿De qué color es el caballo blanco de Santiago?")
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     643         hub_kwargs["_commit_hash"] = config._commit_hash
# ...

# %%
test_model("lxe/Cerebras-GPT-2.7B-Alpaca-SP") #carga bien pero da un warning al final. CORRECTO
# Out:
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1387: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
test_model("vicgalle/gpt-j-6B-alpaca-gpt4") #NotImplementedError: Cannot copy out of meta tensor; no data!
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:870 in pipeline        │
# │                                                                                                  │
# │   867 │   if device is not None:                                                                 │
# │   868 │   │   kwargs["device"] = device                                                          │
# │   869 │                                                                                          │
# ...

# %%
test_model("wxjiao/alpaca-7b") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("MetaIX/Alpaca-30B-Int4") #KeyError: 'llama'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("CyranoB/flan-t5-alpaca-filtered-xxl") #ValueError: Could not load model CyranoB/flan-t5-alpaca-filtered-xxl with any of the following classes:
# Out:
# ...
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:724 in pipeline        │
# │                                                                                                  │
# │   721 │   # Forced if framework already defined, inferred if it's None                           │
# ...

# %%
test_model("MetaIX/Alpaca-30B-Int4-128G-Safetensors")#keyerror llama
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f6d3cfd745cc> in <cell line: 1>()
# ----> 1 test_model("MetaIX/Alpaca-30B-Int4-128G-Safetensors")
#
# <ipython-input-3-35736c78a79c> in test_model(model_name)
#       1 def test_model(model_name):
# ----> 2   generate_text = pipeline(model=model_name, torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto", device=0)
#       3   generate_text("¿De qué color es el caballo blanco de Santiago?")
#
# /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     643         hub_kwargs["_commit_hash"] = config._commit_hash
#     644     elif config is None and isinstance(model, str):
# ...

# %%
test_model("LinhDuong/bloom-7b1-alpaca") #KeyError: 'h.0.mlp.dense_4h_to_h.weight'
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:724 in pipeline        │
# │                                                                                                  │
# │   721 │   # Forced if framework already defined, inferred if it's None                           │
# │   722 │   # Will load the correct model if possible                                              │
# │   723 │   model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}                 │
# ...

# %%
test_model("nenkoru/alpaca-lora-7b-hf-int4")
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("teknium/alpaca-13b-hf-fp16")
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("IlyaGusev/llama_7b_ru_turbo_alpaca_lora_merged")
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("argilla/alpaca-garbage-collector-multilingual")
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:666 in pipeline        │
# │                                                                                                  │
# │   663 │   │   │   │   "Inferring the task automatically requires to check the hub with a model   │
# │   664 │   │   │   │   f"{model} is not a valid model_id."                                        │
# │   665 │   │   │   )                                                                              │
# ...

# %%
test_model("edz3/gpt2-alpaca") #OSError: Can't load tokenizer for 'edz3/gpt2-alpaca'. If you were trying to load it from 
'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make 
sure 'edz3/gpt2-alpaca' is the correct path to a directory containing all relevant files for a GPT2TokenizerFast 
tokenizer.
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:798 in pipeline        │
# │                                                                                                  │
# │   795 │   │   │   │   tokenizer_identifier = tokenizer                                           │
# │   796 │   │   │   │   tokenizer_kwargs = model_kwargs                                            │
# │   797 │   │   │                                                                                  │
# ...

# %%
test_model("MetaIX/Alpaca-30B-Int4-Safetensors")
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:645 in pipeline        │
# │                                                                                                  │
# │   642 │   │   config = AutoConfig.from_pretrained(config, _from_pipeline=task, **hub_kwargs, *   │
# │   643 │   │   hub_kwargs["_commit_hash"] = config._commit_hash                                   │
# │   644 │   elif config is None and isinstance(model, str):                                        │
# ...

# %%
test_model("lxe/Cerebras-GPT-1.3B-Alpaca-SP") #Correcto ha dado un waringn pero lo ha ejecutado bien
# Out:
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1387: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
test_model("0-hero/flan-alpaca-ul2") #ValueError: Could not load model 0-hero/flan-alpaca-ul2 with any of the following classes: (de la clase transformers)
# Out:
# ...
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:724 in pipeline        │
# │                                                                                                  │
# │   721 │   # Forced if framework already defined, inferred if it's None                           │
# ...

# %%
test_model("bertin-project/bertin-gpt-j-6B-alpaca") #NotImplementedError: Cannot copy out of meta tensor; no data!
# Out:
# ...
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:870 in pipeline        │
# │                                                                                                  │
# │   867 │   if device is not None:                                                                 │
# │   868 │   │   kwargs["device"] = device                                                          │
# │   869 │                                                                                          │
# ...

# %%
test_model("VMware/flan-ul2-alpaca-lora")
# Out:
# ...
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ...
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │ in test_model:2                                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/pipelines/__init__.py:724 in pipeline        │
# │                                                                                                  │
# │   721 │   # Forced if framework already defined, inferred if it's None                           │
# ...

# %%
test_model("VMware/flan-t5-large-alpaca")

# %%
test_model("tsumeone/gpt4-x-alpaca-13b-native-4bit-128g-cuda")

# %%
test_model("IlyaGusev/mt0_xxl_ru_turbo_alpaca_lora_merged")

# %%
test_model("lcw99/llama-7B-alpaca-30p")

# %%
test_model("4bit/alpaca-7b-native-4bit")

# %%
test_model("vicgalle/gpt2-alpaca-gpt4")

# %%
test_model("vicgalle/gpt2-alpaca")

# %%
test_model("girish17019/opt-125m-alpaca-sft")

# %%
test_model("osanseviero/llama-alpaca-guanaco-vicuna")

# %%
test_model("larrylawl/alpaca-7b")

# %%
test_model("ArmelR/AlpacaCode512")

# %%
test_model("alexrame/alpaca-lora-7b-merged")

# %%
test_model("Updated 19 days ago")

# %%
test_model("4bit/gpt4-x-alpaca-13b-native-4bit-128g-cuda")

# %%
test_model("vicgalle/alpaca-7b")

# %%
test_model("Selyam/gpt4-x-alpaca-13b-native-4bit-128g")

# %%
test_model("circulus/alpaca-doctor-7b-v2")

# %%
test_model("divineRatio/finetuned_gpt_j_6B_alpaca")

# %%
test_model("Selyam/gpt4-x-alpaca")

# %%
test_model("minlik/chinese-alpaca-7b-merged")

# %%
test_model("Vishnu007/FLAN-T5-Alpaca52k")

# %%
test_model("keyfan/chinese-alpaca-7b-gptq")

# %%
test_model("linkanjarad/GPT2-Medium-Alpaca-355m")

# %%
test_model("Manuel030/alpaca-opt-6.7b")

# %%
test_model("dilab-cau/deft-korean-alpaca")

# %%
test_model("Black-Engineer/llama-30b-sft-oa-alpaca-epoch-2-safetensor")

# %%
test_model("linkanjarad/Bloom-Alpaca-560m")

# %%
test_model("helenai/declare-lab-flan-alpaca-large-ov")

# %%
test_model("theblackcat102/alpaca-title-generator-mt0-large")

# %%
test_model("4bit/gpt4-x-alpaca-13b-native-4bit-128g")

# %%
test_model("circulus/alpaca-base-13b")

# %%
test_model("circulus/alpaca-5.8b-ko")

# %%
test_model("inu-ai/alpaca-guanaco-japanese-gpt-1b")

# %%
test_model("teknium/Base-GPT4-x-Alpaca-Roleplay-Lora")

# %%
test_model("jenoj/chinese-alpaca")

# %%
test_model("dvilasuero/alpaca-bad-instruction-detector")

# %%
test_model("osanseviero/llama-alpaca-snake")

# %%
test_model("gutentag/alpaca-lora")

# %%
test_model("linkanjarad/OPT-Alpaca-125M")

# %%
test_model("minlik/chinese-alpaca-13b-merged")

# %%
test_model("circulus/alpaca-base-7b")

# %%
test_model("nenkoru/alpaca-lora-7b-onnx-fp16-with-past")

# %%
test_model("sdworld/flan-alpaca-xl-ft")

# %%
test_model("DioBrandoTheFirst/gpt4-x-alpaca-13b-native-4bit-128g")

# %%
test_model("crisp-im/alpaca-flan-t5-xl")

# %%
test_model("crisp-im/alpaca-t5-xl")

# %%
test_model("VMware/flan-t5-xl-alpaca")

# %%
test_model("johnrobinsn/alpaca-llama-30b-4bit")

# %%
test_model("152334H/alpaca-7B-fp16")

# %%
test_model("circulus/alpaca-doctor-13b")

# %%
test_model("falkne/flan-alpaca-xl")

# %%
test_model("Muhammadreza/flan-t5-base-alpaca")

# %%
test_model("NbAiLab/nb-gpt-j-6B-alpaca")

# %%
test_model("alpaca/wav2vec2-large-xls-r-300m-demo-zhCN")

# %%
test_model("kcduece/alpaca7B-lora")

# %%
test_model("nenkoru/alpaca-lora-7b-onnx-fp16-no-past")

# %%
test_model("koenraijer/Alpaca-lora")

# %%
test_model("dvilasuero/autotrain-alpaca-gigo-detector-45529113937")

# %%
test_model("crisp-im/alpaca-mt5-base")

# %%
test_model("smjain/flan-alpaca-large-code")

# %%
test_model("quincyqiang/llama-7b-alpaca")

# %%
test_model("helenai/declare-lab-flan-alpaca-xl-ov")

# %%
test_model("nenkoru/alpaca-lora-7b-onnx-fp32-no-past")

# %%
test_model("huggingnft/alpacadabraz")

# %%
test_model("tarunchand/alpaca-native")

# %%
test_model("crisp-im/alpaca-mt5-xl")

# %%
test_model("circulus/alpaca-doctor-7b")

# %%
test_model("trongvox/alpaca7B-lora")

# %%
test_model("japneets/Alpaca_instruction_fine_tune_Punjabi")

# %%
test_model("hackathon-somos-nlp-2023/setfit-alpaca-es-unprocessable-sample-detection")

# %%
test_model("nenkoru/alpaca-lora-7b-onnx-fp32-with-past")

# %%
test_model("dominguesm/alpaca-lora-ptbr-7b")

# %%
test_model("dvilasuero/alpaca-gigo-detector-setfit")

# %%
test_model("CyranoB/flan-t5-alpaca-xxl")

# %%
test_model("rAzOr1/my_alpaca")

# %%
test_model("maxime7770/alpaca7B-test")

# %%
test_model("dvilasuero/alpaca-gigo-detector")

# %%
test_model("hackathon-somos-nlp-2023/setfit-alpaca-es-unprocessable-sample-detection-multi")

# %%
test_model("anamhira/lora-alpaca-gss-large-700")

# %%
test_model("huijian222/Alpaca-LoRA-ZH")

# %%
test_model("Eterna2/alpaca-lora-7b")

# %%
test_model("lopohui/lora-alpaca")

# %%
test_model("kunishou/Japanese-Alpaca-LoRA-7b-v0")

# %%
test_model("kunishou/Japanese-Alpaca-LoRA-13b-v0")

# %%
test_model("chavinlo/alpaca")

# %%
test_model("mrm8488/bloom-7b1-sharded-bf16-finetuned-alpaca-6")

# %%
test_model("kunishou/Japanese-Alpaca-LoRA-30b-v0")

# %%
test_model("HiTZ/alpaca-lora-7b-en-pt-es-ca-eu-gl-at")
