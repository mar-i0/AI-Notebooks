# %% [markdown]
# <a href="https://colab.research.google.com/github/mar-i0/AI-Notebooks/blob/main/Alpaca_LoRa_Miolini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/miolini/alpaca-lora.git
# Out:
# Cloning into 'alpaca-lora'...
# remote: Enumerating objects: 187, done.
# remote: Total 187 (delta 0), reused 0 (delta 0), pack-reused 187
# Receiving objects: 100% (187/187), 6.95 MiB | 3.07 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
cd alpaca-lora
# Out:
# /content/alpaca-lora

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-muhawjtn
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-muhawjtn
#   Resolved https://github.com/huggingface/transformers.git to commit 28f26c107b4a1c5c7e32ed4d9575622da0627a40
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-vo2hfn86
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-vo2hfn86
#   Resolved https://github.com/huggingface/peft.git to commit b21559e042555a8370f4b3cf1ad581c45291cf15
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
# !ls -l
# Out:
# total 22392
# -rw-r--r-- 1 root root 22773992 Apr 15 12:25 alpaca_data.json
# -rw-r--r-- 1 root root    19790 Apr 15 12:25 DATA_LICENSE
# -rw-r--r-- 1 root root     3634 Apr 15 12:25 export_state_dict_checkpoint.py
# -rw-r--r-- 1 root root     4046 Apr 15 12:25 finetune.py
# -rw-r--r-- 1 root root     4161 Apr 15 12:25 generate.py
# -rw-r--r-- 1 root root    82893 Apr 15 12:25 lengths.ipynb
# -rw-r--r-- 1 root root    11396 Apr 15 12:25 LICENSE
# -rw-r--r-- 1 root root    10762 Apr 15 12:25 README.md
# -rw-r--r-- 1 root root      157 Apr 15 12:25 requirements.txt

# %%
# !python generate.py
# Out:
# 2023-04-15 12:27:20.524580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ...
# bin /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:145: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# ...
